# %% [markdown]
# <a href="https://colab.research.google.com/github/Charitha-Perumalla7/DAV-Lab2026-27/blob/main/program2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    "Student_ID":[101,102,103,104,105,106,102,107],
    "Student":["Asha","Ravi","Priya","John","Anu","Kiran","Ravi","Meena"],
    "Department":["CSE","CSE","ECE","ECE","CSE","EEE","CSE","EEE"],
    "Attendence":[90,75,95,60,80,70,75,85],
    "Internal_Marks":[85,70,90,55,78,65,70,None],
    "Final_Marks":[88,72,92,50,80,68,72,82]
}

# %%
df=pd.DataFrame(data)
df.to_csv("student.csv",index=False)
print("student.csv created successfully")
# Out:
# student.csv created successfully

# %%
df=pd.read_csv("student.csv")
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    Student_ID Student Department  Attendence  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          90            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 6         102    Ravi        CSE          75            70.0           72
# 7         107   Meena        EEE          85             NaN           82

# %%
print("\nDataset shape")
print(df.shape)
# Out:
# Dataset shape
# (8, 6)

# %%
print("\nfirst 5 elements")
print(df.head())
# Out:
# first 5 elements
#    Student_ID Student Department  Attendence  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          90            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80

# %%
print("\nlast 5 elements:")
print(df.tail())
# Out:
# last 5 elements:
#    Student_ID Student Department  Attendence  Internal_Marks  Final_Marks
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 6         102    Ravi        CSE          75            70.0           72
# 7         107   Meena        EEE          85             NaN           82

# %%
print("\ndatatype:")
print(df.dtypes)
# Out:
# datatype:
# Student_ID          int64
# Student            object
# Department         object
# Attendence          int64
# Internal_Marks    float64
# Final_Marks         int64
# dtype: object

# %%
print("\nDescrpitive Statistics:")
df.describe()
# Out:
# Descrpitive Statistics:
#        Student_ID  Attendence  Internal_Marks  Final_Marks
# count     8.00000    8.000000        7.000000     8.000000
# mean    103.75000   78.750000       73.285714    75.500000
# std       2.12132   11.259916       11.996031    13.212548
# min     101.00000   60.000000       55.000000    50.000000
# 25%     102.00000   73.750000       67.500000    71.000000
# 50%     103.50000   77.500000       70.000000    76.000000
# 75%     105.25000   86.250000       81.500000    83.500000
# max     107.00000   95.000000       90.000000    92.000000

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Student_ID        0
# Student           0
# Department        0
# Attendence        0
# Internal_Marks    1
# Final_Marks       0
# dtype: int64

# %%
print("\nNumber of Duplicate Values:")
print(df.duplicated().sum())
df=df.drop_duplicates()
# Out:
# Number of Duplicate Values:
# 1

# %%
print(df)
# Out:
#    Student_ID Student Department  Attendence  Internal_Marks  Final_Marks
# 0         101    Asha        CSE          90            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         103   Priya        ECE          95            90.0           92
# 3         104    John        ECE          60            55.0           50
# 4         105     Anu        CSE          80            78.0           80
# 5         106   Kiran        EEE          70            65.0           68
# 7         107   Meena        EEE          85             NaN           82

# %%
print("\nAverage Final Marks in Department:")
print(df.groupby("Department")["Final_Marks"].mean())
# Out:
# Average Final Marks in Department:
# Department
# CSE    80.0
# ECE    71.0
# EEE    75.0
# Name: Final_Marks, dtype: float64

# %%
courses=pd.DataFrame({
    "Student_ID":[101,102,103,104,105,106,102,107],
    "Course":["Python","Java","C","Python","Java","C++","Python","Java"]
})

# %%
merged_df=pd.merge(df,courses,on="Student_ID")
print(merged_df)
# Out:
#    Student_ID Student Department  Attendence  Internal_Marks  Final_Marks  \
# 0         101    Asha        CSE          90            85.0           88
# 1         102    Ravi        CSE          75            70.0           72
# 2         102    Ravi        CSE          75            70.0           72
# 3         103   Priya        ECE          95            90.0           92
# 4         104    John        ECE          60            55.0           50
# 5         105     Anu        CSE          80            78.0           80
# 6         106   Kiran        EEE          70            65.0           68
# 7         107   Meena        EEE          85             NaN           82
#
#    Course
# 0  Python
# 1    Java
# 2  Python
# 3       C
# 4  Python
# 5    Java
# 6     C++
# 7    Java
