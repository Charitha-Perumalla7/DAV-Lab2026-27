# %% [markdown]
# <a href="https://colab.research.google.com/github/Charitha-Perumalla7/DAV-Lab2026-27/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    "Student":["S1","S2","S3","S4","S5","S6","S7","S8","S9","S10"],
    "Study_hours":[2,3,4,5,6,7,8,9,4,5],
    "Attendence":[86,70,75,89,90,100,90,69,95,83],
    "Internal_Marks":[90,76,54,89,90,100,98,78,92,69],
    "Final_Marks":[90,77,89,73,88,100,79,86,96,70]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Student  Study_hours  Attendence  Internal_Marks  Final_Marks
# 0      S1            2          86              90           90
# 1      S2            3          70              76           77
# 2      S3            4          75              54           89
# 3      S4            5          89              89           73
# 4      S5            6          90              90           88
# 5      S6            7         100             100          100
# 6      S7            8          90              98           79
# 7      S8            9          69              78           86
# 8      S9            4          95              92           96
# 9     S10            5          83              69           70

# %%
plt.hist(df["Final_Marks"], bins=5)
plt.xlabel("Final Marks")
plt.ylabel("Frequency")
plt.title("Histogram of Final Marks")
plt.show()

# %%
plt.boxplot(df["Final_Marks"])
plt.xlabel("Final Marks")
plt.title("Boxplot of Final Marks")
plt.show()

# %%
plt.boxplot([
    df['Study_hours'],
    df['Attendence'],
    df['Internal_Marks'],
    df['Final_Marks']
])

plt.xticks(
    [1,2,3,4],
    ["Study_hours","Attendence","Internal_Marks","Final_Marks"]
)
plt.ylabel("Marks")
plt.title("Boxplot of Marks")
plt.show()

# %%
import seaborn as c
c.pairplot(
    df[
        [
            "Study_hours",
            "Attendence",
            "Internal_Marks",
            "Final_Marks"
        ]
    ]
)
plt.show()

# %%
c.heatmap(df.corr(numeric_only=True),annot=True)
plt.title("Coorelation Heatmap")
plt.show()
