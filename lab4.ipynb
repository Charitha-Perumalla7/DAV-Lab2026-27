# %% [markdown]
# <a href="https://colab.research.google.com/github/Charitha-Perumalla7/DAV-Lab2026-27/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
df=pd.DataFrame({
    "Marks":[80,70,None,90,60],
    "Attendence":[90,None,85,80,75],
    "Department":["CSE","ECE","EEE",None,"CSE"]
}
)
df["Marks"]=df["Marks"].fillna(df["Marks"].mean())
df["Attendence"]=df["Attendence"].fillna(df["Attendence"].median())
df["Attendence"]=df["Attendence"].ffill()
df["Department"]=df["Department"].fillna(df["Department"].mode()[0])

# %%
encoder=LabelEncoder()
df["Department"]=encoder.fit_transform(df["Department"])
print(df)
# Out:
#    Marks  Attendence  Department
# 0   80.0        90.0           0
# 1   70.0        82.5           1
# 2   75.0        85.0           2
# 3   90.0        80.0           0
# 4   60.0        75.0           0
